# %%
avgwithpruning = [0.8028235294117648, 0.8932048192771082, 0.923012345679013, 0.9283291139240507, 0.9351428571428575, 
                  0.9397866666666664, 0.9397534246575339, 0.9372676056338036, 0.9452173913043493, 0.9454029850746266, 
                  0.9467999999999992, 0.9466349206349196, 0.9475737704918034, 0.9493220338983046, 0.9482456140350873,
                  0.9490545454545452, 0.949509433962264, 0.9494509803921559, 0.9484081632653062, 0.9477872340425536, 
                  0.9526222222222218, 0.950790697674419, 0.9495121951219516, 0.9503076923076914, 0.9493513513513512,
                  0.9535428571428569, 0.948545454545455, 0.953806451612903, 0.9497241379310356, 0.9541481481481475]

avgwithoutpruning = [0.8374117647058823, 0.9117590361445784, 0.9204444444444445, 0.9272911392405065, 0.9331948051948048,
                     0.9356266666666668, 0.9284109589041093, 0.9333802816901414, 0.9336231884057983, 0.9331343283582089, 
                     0.9313846153846153, 0.9343174603174594, 0.9343606557377049, 0.9360338983050847, 0.9378596491228073, 
                     0.9347999999999999, 0.9367169811320751, 0.9350196078431365, 0.9323265306122452, 0.9367234042553193,
                     0.9353777777777781, 0.9341395348837213, 0.9371219512195127, 0.9341538461538451, 0.9351351351351356,
                     0.9375999999999998, 0.9332121212121212, 0.9381935483870965, 0.9337241379310346, 0.9387407407407402]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = range(10, 310, 10)
fig, ax = plt.subplots()
ax.plot(x, avgwithpruning, 'g', label='with pruning')
ax.plot(x, avgwithoutpruning, 'r', label='without pruning')
legend = ax.legend(loc='lower center', shadow=True, fontsize='x-large')
plt.ylabel('Accuracy')
plt.xlabel('Size of training dataset (including validation set)')
fig.savefig('accuracy.png') 
plt.show()

# %%
% run unit_tests.py
